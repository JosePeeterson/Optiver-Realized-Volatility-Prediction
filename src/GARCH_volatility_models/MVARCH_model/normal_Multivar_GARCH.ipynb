# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/MyDrive/optiver_real_vol')

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')


# !pip install git+https://github.com/mawicks/mvarch
# Out:
# Mounted at /content/drive
# /bin/bash: line 1: nvidia-smi: command not found
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!
# Collecting git+https://github.com/mawicks/mvarch
#   Cloning https://github.com/mawicks/mvarch to /tmp/pip-req-build-mfwivtu2
#   Running command git clone --filter=blob:none --quiet https://github.com/mawicks/mvarch /tmp/pip-req-build-mfwivtu2
#   Resolved https://github.com/mawicks/mvarch to commit b6cb66f24f1f4b74d80daf625fffbbc5b87f2226
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: click>=8 in /usr/local/lib/python3.10/dist-packages (from mvarch==0.1.1) (8.1.7)
# Collecting coverage<7.0.0,>=6.4.4 (from mvarch==0.1.1)
#   Downloading coverage-6.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.3/213.3 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from mvarch==0.1.1) (1.25.2)
# Requirement already satisfied: pandas>=1 in /usr/local/lib/python3.10/dist-packages (from mvarch==0.1.1) (1.5.3)
# Collecting pylint<3.0.0,>=2.15.0 (from mvarch==0.1.1)
#   Downloading pylint-2.17.7-py3-none-any.whl (537 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 537.2/537.2 kB 22.9 MB/s eta 0:00:00
# Collecting pytz<2023.0,>=2022.1 (from mvarch==0.1.1)
#   Downloading pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 45.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1 in /usr/local/lib/python3.10/dist-packages (from mvarch==0.1.1) (2.2.1+cu121)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.10/dist-packages (from mvarch==0.1.1) (2.0.7)
# Requirement already satisfied: yfinance>=0.1 in /usr/local/lib/python3.10/dist-packages (from mvarch==0.1.1) (0.2.37)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1->mvarch==0.1.1) (2.8.2)
# Requirement already satisfied: platformdirs>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from pylint<3.0.0,>=2.15.0->mvarch==0.1.1) (4.2.0)
# Collecting astroid<=2.17.0-dev0,>=2.15.8 (from pylint<3.0.0,>=2.15.0->mvarch==0.1.1)
#   Downloading astroid-2.15.8-py3-none-any.whl (278 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.3/278.3 kB 26.2 MB/s eta 0:00:00
# Collecting isort<6,>=4.2.5 (from pylint<3.0.0,>=2.15.0->mvarch==0.1.1)
#   Downloading isort-5.13.2-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.3/92.3 kB 10.0 MB/s eta 0:00:00
# Collecting mccabe<0.8,>=0.6 (from pylint<3.0.0,>=2.15.0->mvarch==0.1.1)
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Collecting tomlkit>=0.10.1 (from pylint<3.0.0,>=2.15.0->mvarch==0.1.1)
#   Downloading tomlkit-0.12.4-py3-none-any.whl (37 kB)
# Collecting dill>=0.2 (from pylint<3.0.0,>=2.15.0->mvarch==0.1.1)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from pylint<3.0.0,>=2.15.0->mvarch==0.1.1) (2.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1->mvarch==0.1.1) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1->mvarch==0.1.1) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1->mvarch==0.1.1) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1->mvarch==0.1.1) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1->mvarch==0.1.1) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1->mvarch==0.1.1) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1->mvarch==0.1.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 50.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1->mvarch==0.1.1)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 57.1 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1->mvarch==0.1.1)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 78.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1->mvarch==0.1.1)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1->mvarch==0.1.1)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.9 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1->mvarch==0.1.1)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 12.8 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1->mvarch==0.1.1)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 27.6 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1->mvarch==0.1.1)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 5.2 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1->mvarch==0.1.1)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.3 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1->mvarch==0.1.1)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.3 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1->mvarch==0.1.1)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1->mvarch==0.1.1) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1->mvarch==0.1.1)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 69.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1->mvarch==0.1.1) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1->mvarch==0.1.1) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1->mvarch==0.1.1) (4.9.4)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1->mvarch==0.1.1) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1->mvarch==0.1.1) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1->mvarch==0.1.1) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1->mvarch==0.1.1) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1->mvarch==0.1.1) (1.1)
# Collecting lazy-object-proxy>=1.4.0 (from astroid<=2.17.0-dev0,>=2.15.8->pylint<3.0.0,>=2.15.0->mvarch==0.1.1)
#   Downloading lazy_object_proxy-1.10.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.3/68.3 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2,>=1.11 in /usr/local/lib/python3.10/dist-packages (from astroid<=2.17.0-dev0,>=2.15.8->pylint<3.0.0,>=2.15.0->mvarch==0.1.1) (1.14.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance>=0.1->mvarch==0.1.1) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance>=0.1->mvarch==0.1.1) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance>=0.1->mvarch==0.1.1) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance>=0.1->mvarch==0.1.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance>=0.1->mvarch==0.1.1) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance>=0.1->mvarch==0.1.1) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1->mvarch==0.1.1) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1->mvarch==0.1.1) (1.3.0)
# Building wheels for collected packages: mvarch
#   Building wheel for mvarch (pyproject.toml) ... done
#   Created wheel for mvarch: filename=mvarch-0.1.1-py3-none-any.whl size=37841 sha256=2dade043ac1e5d191dacc1425327e7ebc4b1c5f5ba5b7886f317ca9f6c4ddf4c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r01qkxyf/wheels/2a/e3/8e/b0a3d07732801542b1529c607513e2b486dce933188505c204
# Successfully built mvarch
# Installing collected packages: pytz, tomlkit, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mccabe, lazy-object-proxy, isort, dill, coverage, nvidia-cusparse-cu12, nvidia-cudnn-cu12, astroid, pylint, nvidia-cusolver-cu12, mvarch
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2023.4
#     Uninstalling pytz-2023.4:
#       Successfully uninstalled pytz-2023.4
# Successfully installed astroid-2.15.8 coverage-6.5.0 dill-0.3.8 isort-5.13.2 lazy-object-proxy-1.10.0 mccabe-0.7.0 mvarch-0.1.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 pylint-2.17.7 pytz-2022.7.1 tomlkit-0.12.4

# %%
import pickle
from datetime import datetime
import os
import gc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go
import seaborn as sns

import xgboost as xgb
from sklearn.preprocessing import OneHotEncoder
from xgboost import plot_tree
from sklearn.utils import class_weight
from xgboost import plot_importance

from sklearn.model_selection import RepeatedKFold, cross_val_score, TimeSeriesSplit

import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from statsmodels.genmod.generalized_linear_model import GLM
import scipy.stats as stats

from sklearn.cluster import KMeans
import re

import warnings
#warnings.filterwarnings("ignore")
from sklearn.metrics import confusion_matrix
#from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay


from sklearn.utils import class_weight

from mlxtend.evaluate import bias_variance_decomp

import mvarch
import numpy as np

import sys
from sklearn import covariance

from sklearn import cluster

from sklearn import manifold

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection

import torch

# %%
## load dataset

## cumulative log returns in first 10 mins.
os.chdir('/content/drive/MyDrive/optiver_real_vol/Datasets')
log_return_book_wap1_df = pickle.load(open('log_return_book_wap1_df.pkl','rb'))
log_return_trade_df = pickle.load(open('log_return_trade_df.pkl','rb'))

log_return_book_wap1_df['time_id'] = log_return_book_wap1_df.index.values
log_return_trade_df['time_id'] = log_return_trade_df.index.values


## GROUND TRUTH Realized Volatitlies
os.chdir('/content/drive/MyDrive/optiver_real_vol/Datasets')
first_10_min_wap1_vol_df = pickle.load(open('first_10_min_wap1_vol_df.pkl','rb'))

os.chdir('/content/drive/MyDrive/optiver_real_vol/Datasets')
first_10_min_trade_price_vol_df = pickle.load(open('trade_price_real_vol_df.pkl','rb'))



reordered_time_ids = log_return_book_wap1_df['time_id'].values
log_return_book_wap1_df = log_return_book_wap1_df.drop(columns=['time_id'])
log_return_trade_df = log_return_trade_df.drop(columns=['time_id'])
unique_stock_ids = log_return_book_wap1_df.columns.values
unique_stock_ids = np.array([str(s) for s in unique_stock_ids])

# %%
###### check that there are no +/-inf and nan values

if (
log_return_book_wap1_df.isna().sum().sum()+
log_return_trade_df.isna().sum().sum() != 0):
    print('there are nan values')

if (
log_return_book_wap1_df.isin([np.inf, -np.inf]).sum().sum()+
log_return_trade_df.isin([np.inf, -np.inf]).sum().sum()  != 0):
    print('there are inf values')

# %%
def plot_embedding_n_visualize_graph(X, labels,title_name):

    node_position_model = manifold.LocallyLinearEmbedding(
        n_components=2, eigen_solver="dense", n_neighbors=6
    )

    embedding = node_position_model.fit_transform(X.T).T



    plt.figure(1, facecolor="w", figsize=(35, 30))

    plt.clf()
    ax = plt.axes([0.0, 0.0, 1.0, 1.0])
    plt.axis("off")

    # Plot the graph of partial correlations
    partial_correlations = edge_model.precision_.copy()
    d = 1 / np.sqrt(np.diag(partial_correlations))
    partial_correlations *= d
    partial_correlations *= d[:, np.newaxis]
    non_zero = np.abs(np.triu(partial_correlations, k=1)) > 0.02

    # Plot the nodes using the coordinates of our embedding
    plt.scatter(
        embedding[0], embedding[1], s=100 * d**2, c=labels, cmap=plt.cm.nipy_spectral
    )

    # Plot the edges
    start_idx, end_idx = np.where(non_zero)
    # a sequence of (*line0*, *line1*, *line2*), where::
    #            linen = (x0, y0), (x1, y1), ... (xm, ym)
    segments = [
        [embedding[:, start], embedding[:, stop]] for start, stop in zip(start_idx, end_idx)
    ]
    values = np.abs(partial_correlations[non_zero])
    lc = LineCollection(
        segments, zorder=0, cmap=plt.cm.hot_r, norm=plt.Normalize(0, 0.7 * values.max())
    )
    lc.set_array(values)
    lc.set_linewidths(15 * values)
    ax.add_collection(lc)

    # Add a label to each node. The challenge here is that we want to
    # position the labels to avoid overlap with other labels
    for index, (name, label, (x, y)) in enumerate(zip(names, labels, embedding.T)):
        dx = x - embedding[0]
        dx[index] = 1
        dy = y - embedding[1]
        dy[index] = 1
        this_dx = dx[np.argmin(np.abs(dy))]
        this_dy = dy[np.argmin(np.abs(dx))]
        if this_dx > 0:
            horizontalalignment = "left"
            x = x + 0.002
        else:
            horizontalalignment = "right"
            x = x - 0.002
        if this_dy > 0:
            verticalalignment = "bottom"
            y = y + 0.002
        else:
            verticalalignment = "top"
            y = y - 0.002
        plt.text(
            x,
            y,
            name,
            size=10,
            horizontalalignment=horizontalalignment,
            verticalalignment=verticalalignment,
            bbox=dict(
                facecolor="w",
                edgecolor=plt.cm.nipy_spectral(label / float(n_labels)),
                alpha=0.6,
            ),
        )

    plt.xlim(
        embedding[0].min() - 0.15 * np.ptp(embedding[0]),
        embedding[0].max() + 0.10 * np.ptp(embedding[0]),
    )
    plt.ylim(
        embedding[1].min() - 0.03 * np.ptp(embedding[1]),
        embedding[1].max() + 0.03 * np.ptp(embedding[1]),
    )
    plt.title(f'clusters of {title_name}',fontsize = 40)
    plt.show()

    return

# %%
"""
GraphicalLassoCV
Visualize, inverse covariance/ precision / conditional correlation matrix
Cluster using affinity propagation
Dimensionality reduction and graph visualization
"""

def find_ret_corr_n_cluster(market_structure_data,name):

    """
    GraphicalLassoCV
    """

    alphas = np.logspace(-0.5, 1, num=10)
    edge_model = covariance.GraphicalLassoCV(alphas=alphas)

    # standardize the time series: using correlations rather than covariance
    # former is more efficient for structure recovery
    X = market_structure_data.to_numpy() # variation.copy().T
    X /= X.std(axis=0)
    edge_model.fit(X)


    """
    Visualize, inverse covariance/ precision / conditional correlation matrix
    """
    p = edge_model.precision_
    ax = plt.axes()
    sns.heatmap(data=p,ax=ax)
    ax.set_title(f'precision matrix of {name}')
    plt.show()


    """
    Cluster using affinity propagation
    """
    _, labels = cluster.affinity_propagation(edge_model.covariance_, random_state=0)
    n_labels = labels.max()

    cols = log_return_book_wap1_df.columns
    names = cols

    cluster_dict = {}
    print('\n')
    for i in range(n_labels + 1):
        #print(f"Cluster {i + 1}: {list(names[labels == i].values)}, Number of stocks: {len(names[labels == i].values)}")
        cluster_dict[i] = list(names[labels == i].values)


    """
    Dimensionality reduction and graph visualization
    """
    print('\n')
    #plot_embedding_n_visualize_graph(X, labels, name)

    return cluster_dict

# %%
def mvarch_train_predict(mvarch_data,multivariate,device,returns_distrbution,mean):

    model = mvarch.model_factory(distribution= returns_distrbution, mean=mean, univariate="arch", constraint="scalar",multivariate=multivariate,device=device)

    fit_history = mvarch_data.values
    model.fit(fit_history)
    #print(f"Likelihood: {model.mean_log_likelihood(fit_history):.4f}")

    TAIL_SIZE = 1
    evaluate_history = mvarch_data.iloc[-TAIL_SIZE:].values

    (
        mv_scale_predicted,
        uv_scale_predicted,
        mean_predicted,
        mv_scale_history,
        uv_scale_history,
        mean_history,
    ) = model.predict(evaluate_history)

    next_time_id_uv_scale_predicted = (uv_scale_predicted * model.distribution.std_dev()).numpy()
    #next_time_id_uv_scale_predicted = (uv_scale_predicted * model.distribution.std_dev()).cpu().numpy()

    # print(
    #     f"Next time id volatility prediction:\n"
    #     f"{next_time_id_uv_scale_predicted}\n"
    # )

    next_time_id_mv_scale_predicted = (mv_scale_predicted @ mv_scale_predicted.T).numpy()
    #next_time_id_mv_scale_predicted = (mv_scale_predicted @ mv_scale_predicted.T).cpu().numpy()

    # print(
    #     f"Next time id correlation prediction:\n"
    #     f"{next_time_id_mv_scale_predicted}"
    # )


    # print(
    #     f"uv_scale_history:\n"
    #     f"{uv_scale_history }"
    # )

    # print(
    #     f"correlation. mv_scale_history:\n"
    #     f"{(mv_scale_history @ mv_scale_history.T).numpy()}"
    # )
    return next_time_id_uv_scale_predicted, next_time_id_mv_scale_predicted, model.distribution.std_dev()

# %%
"""
Total time ids = 3830

split raw data into 3830//(9*22)) = 19.34 months / regimes.
63*9*2 = 1134 time ids each regime.

[   0  198  396  594  792  990 1188 1386 1584 1782 1980 2178 2376 2574 2772 2970 3168 3366 3564 3762 3831]
"""
split_idxs_into_regimes = np.array([])
Num_of_regimes = 22*9

for i in range(0,3831,Num_of_regimes): # split raw data into 3830//(9*22)) = 19.34 months
    split_idxs_into_regimes = np.append(split_idxs_into_regimes,i)
split_idxs_into_regimes = np.append(split_idxs_into_regimes,3831).astype(int)
print(split_idxs_into_regimes)
# Out:
# [   0  198  396  594  792  990 1188 1386 1584 1782 1980 2178 2376 2574
#  2772 2970 3168 3366 3564 3762 3831]

# %%
"""
MVARCH Training routine

"""

# Initialize DataFrame outside the loop
all_mvarch_uv_rvol_predicted_df = pd.DataFrame(columns=unique_stock_ids, index=reordered_time_ids)
all_mvarch_uv_model_std_predicted_df = pd.DataFrame(columns=unique_stock_ids, index=reordered_time_ids)
all_times_corr_matrix_dict = {}


tid_per_day = 9
days = 10  # 22 days_per_month, # 5 days_per_week , 10 days = 2 weeks
train_tid_length = tid_per_day * days  # time ids per month
split_idxs_into_regimes[-1] =  split_idxs_into_regimes[-1] - train_tid_length # to prevent overflow

def mvarch_regime_training(regime):

    for l in [regime]: #range(len(split_idxs_into_regimes) - 20): # -20
        start_idx = split_idxs_into_regimes[l]
        end_idx = split_idxs_into_regimes[l+1]
        print(f"start_idx: {start_idx}, end_idx: {end_idx}")

        name= 'log_return_book_wap1_df'
        market_structure_data = log_return_book_wap1_df.iloc[start_idx:end_idx + train_tid_length] # start_idx + train_tid_length to prevent lookahead bias

        # name= 'log_return_trade_df'
        # market_structure_data = log_return_trade_df.iloc[start_idx:end_idx - train_tid_length]

        cluster_dict = find_ret_corr_n_cluster(market_structure_data,name)

        if name == 'log_return_book_wap1_df':
            training_data = log_return_book_wap1_df
        elif name == 'log_return_trade_df':
            training_data = log_return_trade_df


        ###################### OPTIMIZED MVARCH routine ###############################

        # Define constants and parameters
        increment = 1
        start_tr_idx = start_idx
        end_tr_idx = end_idx # - train_tid_length # 3832 - train_tid_length
        sub_clust_len = 5 # number of stocks in sub-cluster.

        #device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        # Loop over time indices
        for start_time_idx in range(start_tr_idx, end_tr_idx, increment):
            end_time_idx = start_time_idx + train_tid_length
            print("\n\n")
            print(f"Start time index: {start_time_idx}, End time index: {end_time_idx}")
            print(f"time id start: {reordered_time_ids[start_time_idx]}, time id end: {reordered_time_ids[end_time_idx]}")

            # Get the book wap1 training data for this window
            train_df = training_data.iloc[start_time_idx:end_time_idx]

            time_id_corr_matrix_df = pd.DataFrame(columns=unique_stock_ids, index=unique_stock_ids)

            for c in cluster_dict.keys():
                clust_len = len(cluster_dict[c])  # remaining cluster length
                clust_stocks = cluster_dict[c]

                # Split clusters into subsets
                for i in range(0, clust_len, sub_clust_len):
                    clust_subset_stocks = clust_stocks[i:i + sub_clust_len]
                    subset_df = train_df[clust_subset_stocks]
                    print(f"Cluster {c + 1}: {clust_subset_stocks}, Number of stocks: {len(clust_subset_stocks)}")

                    next_time_id_uv_scale_predicted, next_time_id_mv_scale_predicted, model_Std = mvarch_train_predict(subset_df, multivariate='mvarch',device='cpu',returns_distrbution='normal',mean='constant' )

                    # Update predictions DataFrame
                    clust_subset_stocks = [str(x) for x in clust_subset_stocks]
                    all_mvarch_uv_rvol_predicted_df.iloc[end_time_idx + 1][clust_subset_stocks] = next_time_id_uv_scale_predicted
                    all_mvarch_uv_model_std_predicted_df.iloc[end_time_idx + 1][clust_subset_stocks] = model_Std

                    # Update correlation matrix DataFrame
                    for i, stock_i in enumerate(clust_subset_stocks):
                        for j, stock_j in enumerate(clust_subset_stocks):
                            time_id_corr_matrix_df.loc[stock_i, stock_j] = next_time_id_mv_scale_predicted[i][j]

            all_times_corr_matrix_dict[end_time_idx + 1] = time_id_corr_matrix_df


    #### save them to not lose them for further analysis

    os.chdir('/content/drive/MyDrive/optiver_real_vol/Datasets/mvarch_features/results/normal_Regimes')
    pickle.dump(all_mvarch_uv_rvol_predicted_df, open('mvarch_uv_rvol_pred_df_normal_constant_u_'+name+'_'+str(regime)+'.pkl', 'wb') )
    pickle.dump(all_times_corr_matrix_dict, open('mvarch_corr_mat_dict_normal_constant_u_'+name+'_'+str(regime)+'.pkl', 'wb'))
    #pickle.dump(all_mvarch_uv_model_std_predicted_df, open('mvarch_uv_model_std_predicted_df_normal_constant_u_'+name+'_'+str(regime)+'.pkl', 'wb'))

    return

# %%
"""
Save individual regimes independently to not lose them for further analysis

"""
for regime in range(0,len(split_idxs_into_regimes),1 ): # -20
    print(f"regime: {regime}")
    mvarch_regime_training(regime)
# Out:
# regime: 0
# start_idx: 0, end_idx: 198
# Start time index: 0, End time index: 90
# time id start: 4294, time id end: 19090
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 1, End time index: 91
# time id start: 31984, time id end: 1822
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 2, End time index: 92
# time id start: 31570, time id end: 8426
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 3, End time index: 93
# time id start: 5666, time id end: 13124
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 4, End time index: 94
# time id start: 29740, time id end: 2075
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 5, End time index: 95
# time id start: 22178, time id end: 7447
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 6, End time index: 96
# time id start: 13217, time id end: 12957
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 7, End time index: 97
# time id start: 16992, time id end: 7677
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 8, End time index: 98
# time id start: 20135, time id end: 19554
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 9, End time index: 99
# time id start: 12011, time id end: 11886
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 10, End time index: 100
# time id start: 24033, time id end: 13491
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 11, End time index: 101
# time id start: 13421, time id end: 25680
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 12, End time index: 102
# time id start: 20351, time id end: 15846
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 13, End time index: 103
# time id start: 13473, time id end: 4927
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 14, End time index: 104
# time id start: 31173, time id end: 30986
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 15, End time index: 105
# time id start: 4743, time id end: 26021
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 16, End time index: 106
# time id start: 9077, time id end: 20196
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 17, End time index: 107
# time id start: 18940, time id end: 10070
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 18, End time index: 108
# time id start: 250, time id end: 29120
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 19, End time index: 109
# time id start: 4543, time id end: 2600
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 20, End time index: 110
# time id start: 24661, time id end: 12486
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 21, End time index: 111
# time id start: 6619, time id end: 11809
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 22, End time index: 112
# time id start: 16454, time id end: 18445
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 23, End time index: 113
# time id start: 28422, time id end: 10938
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 24, End time index: 114
# time id start: 9664, time id end: 18628
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 25, End time index: 115
# time id start: 27071, time id end: 2591
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 26, End time index: 116
# time id start: 7818, time id end: 25570
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 27, End time index: 117
# time id start: 9166, time id end: 30512
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 28, End time index: 118
# time id start: 26308, time id end: 5206
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 29, End time index: 119
# time id start: 28993, time id end: 5793
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# ...
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 111, End time index: 201
# time id start: 11809, time id end: 22013
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 112, End time index: 202
# time id start: 18445, time id end: 27851
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 113, End time index: 203
# time id start: 10938, time id end: 18072
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# Cluster 1: [119], Number of stocks: 1
# Cluster 2: [11, 15, 26, 31, 37], Number of stocks: 5
# Cluster 2: [41, 87, 111], Number of stocks: 3
# Cluster 3: [16, 60, 74, 82, 95], Number of stocks: 5
# Cluster 3: [105], Number of stocks: 1
# Cluster 4: [19, 39, 59, 64, 68], Number of stocks: 5
# Cluster 4: [85, 114], Number of stocks: 2
# Cluster 5: [21, 28, 35, 83], Number of stocks: 4
# Cluster 6: [6, 23, 29, 33, 36], Number of stocks: 5
# Cluster 6: [43, 44, 52, 56, 61], Number of stocks: 5
# Cluster 6: [70, 73, 103, 104, 107], Number of stocks: 5
# Cluster 6: [113, 124], Number of stocks: 2
# Cluster 7: [38], Number of stocks: 1
# Cluster 8: [4, 48, 120], Number of stocks: 3
# Cluster 9: [13, 51, 77], Number of stocks: 3
# Cluster 10: [10, 55, 62, 80, 96], Number of stocks: 5
# Cluster 10: [110, 126], Number of stocks: 2
# Cluster 11: [20, 53, 72, 108], Number of stocks: 4
# Cluster 12: [3, 9, 27, 46, 47], Number of stocks: 5
# Cluster 12: [50, 76, 78, 88, 90], Number of stocks: 5
# Cluster 12: [109, 118, 125], Number of stocks: 3
# Cluster 13: [86], Number of stocks: 1
# Cluster 14: [8, 63, 84, 89, 100], Number of stocks: 5
# Cluster 14: [123], Number of stocks: 1
# Cluster 15: [58, 99], Number of stocks: 2
# Cluster 16: [5, 101], Number of stocks: 2
# Cluster 17: [0, 1, 7, 17, 18], Number of stocks: 5
# Cluster 17: [22, 30, 42, 66, 69], Number of stocks: 5
# Cluster 17: [75, 81, 97, 102, 112], Number of stocks: 5
# Cluster 17: [116, 122], Number of stocks: 2
# Cluster 18: [2, 93, 94, 98, 115], Number of stocks: 5
#
#
#
# Start time index: 114, End time index: 204
# time id start: 18628, time id end: 17210
# Cluster 1: [14, 32, 34, 40, 67], Number of stocks: 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-e8034c45eb1d> in <cell line: 5>()
#       5 for regime in range(0,len(split_idxs_into_regimes),1 ): # -20
#       6     print(f"regime: {regime}")
# ----> 7     mvarch_regime_training(regime)
#       8
#       9
#
# <ipython-input-10-b99fe9ab342e> in mvarch_regime_training(regime)
#      68                     print(f"Cluster {c + 1}: {clust_subset_stocks}, Number of stocks: {len(clust_subset_stocks)}")
#      69
# ---> 70                     next_time_id_uv_scale_predicted, next_time_id_mv_scale_predicted, model_Std = mvarch_train_predict(subset_df, multivariate='mvarch',device='cpu',returns_distrbution='normal',mean='constant' )
#      71
#      72                     # Update predictions DataFrame
#
# <ipython-input-8-a6b59779ca5d> in mvarch_train_predict(mvarch_data, multivariate, device, returns_distrbution, mean)
#       4
#       5     fit_history = mvarch_data.values
# ----> 6     model.fit(fit_history)
#       7     #print(f"Likelihood: {model.mean_log_likelihood(fit_history):.4f}")
#       8
#
# /usr/local/lib/python3.10/dist-packages/mvarch/multivariate_models.py in fit(self, observations)
#     415
#     416         if self.univariate_model.is_optimizable:
# --> 417             self.univariate_model.fit(observations)
#     418             uv_scale, uv_mean = self.univariate_model.predict(observations)[2:]
#     419             centered_observations = observations - uv_mean
#
# /usr/local/lib/python3.10/dist-packages/mvarch/univariate_models.py in fit(self, observations)
#     145             return float(loss)
#     146
# --> 147         optimize(optim, loss_closure, "univariate model")
#     148
#     149         self.distribution.log_parameters()
#
# /usr/local/lib/python3.10/dist-packages/mvarch/optimize.py in optimize(optim, closure, label)
#      27     logging.info(f"Starting {label}" + (" " if label else "") + "optimization")
#      28     while not done:
# ---> 29         optim.step(closure)
#      30         current_loss = closure()
#      31         logging.info(f"\tCurrent loss: {current_loss:.4f}")
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     383                             )
#     384
# --> 385                 out = func(*args, **kwargs)
#     386                 self._optimizer_step_code()
#     387
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/lbfgs.py in step(self, closure)
#     426                         return self._directional_evaluate(closure, x, t, d)
#     427
# --> 428                     loss, flat_grad, t, ls_func_evals = _strong_wolfe(
#     429                         obj_func, x_init, t, d, loss, flat_grad, gtd)
#     430                 self._add_grad(t, d)
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/lbfgs.py in _strong_wolfe(obj_func, x, t, d, f, g, gtd, c1, c2, tolerance_change, max_ls)
#     146
#     147         # Evaluate new point
# --> 148         f_new, g_new = obj_func(x, t, d)
#     149         ls_func_evals += 1
#     150         gtd_new = g_new.dot(d)
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/lbfgs.py in obj_func(x, t, d)
#     424
#     425                     def obj_func(x, t, d):
# --> 426                         return self._directional_evaluate(closure, x, t, d)
#     427
#     428                     loss, flat_grad, t, ls_func_evals = _strong_wolfe(
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/lbfgs.py in _directional_evaluate(self, closure, x, t, d)
#     278     def _directional_evaluate(self, closure, x, t, d):
#     279         self._add_grad(t, d)
# --> 280         loss = float(closure())
#     281         flat_grad = self._gather_flat_grad()
#     282         self._set_param(x)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/mvarch/univariate_models.py in loss_closure()
#     141                 self.log_parameters()
#     142             optim.zero_grad()
# --> 143             loss = -self.__mean_log_likelihood(observations)
#     144             loss.backward()
#     145             return float(loss)
#
# /usr/local/lib/python3.10/dist-packages/mvarch/univariate_models.py in __mean_log_likelihood(self, observations)
#     176         centered_observations = observations - mu
#     177         scale = self._predict(centered_observations)[1]
# --> 178         mean_ll = marginal_conditional_log_likelihood(
#     179             centered_observations, scale, self.distribution.get_instance()
#     180         )
#
# /usr/local/lib/python3.10/dist-packages/mvarch/univariate_models.py in marginal_conditional_log_likelihood(centered_observations, scale, distribution)
#      41
#      42     # Compute the log likelihoods on the innovations
# ---> 43     ll = distribution.log_prob(scaled_observations) - torch.log(scale)
#      44
#      45     # For consistency with the multivariate case, we *sum* over the
#
# /usr/local/lib/python3.10/dist-packages/torch/distributions/normal.py in log_prob(self, value)
#      77     def log_prob(self, value):
#      78         if self._validate_args:
# ---> 79             self._validate_sample(value)
#      80         # compute the variance
#      81         var = self.scale**2
#
# /usr/local/lib/python3.10/dist-packages/torch/distributions/distribution.py in _validate_sample(self, value)
#     310         valid = support.check(value)
#     311         if not valid.all():
# --> 312             raise ValueError(
#     313                 "Expected value argument "
#     314                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#
# ValueError: Expected value argument (Tensor of shape (90, 5)) to be within the support (Real()) of the distribution Normal(loc: 0.0, scale: 1.0), but found invalid values:
# tensor([[nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan]], grad_fn=<DivBackward0>)

# %%
"""
Evaluate Mvarch predictions on book wap1 volatilities.

"""

os.chdir('/content/drive/MyDrive/optiver_real_vol/Datasets/mvarch_features/results/normal_Regimes')
all_mvarch_uv_rvol_predicted_df_mean_constant = pickle.load( open('mvarch_uv_rvol_pred_df_normal_constant_u_log_return_book_wap1_df_0.pkl', 'rb'))
all_times_corr_matrix_dict_mean_constant = pickle.load( open('mvarch_corr_mat_dict_normal_constant_u_log_return_book_wap1_df_0.pkl', 'rb'))
#all_mvarch_uv_model_std_predicted_df_mean_constant = pickle.load( open('mvarch_uv_model_std_predicted_df_normal_constant_u_log_return_book_wap1_df_0.pkl', 'rb'))

############## Book WAP1 volotitliy start ##############
########################################################
first_10_min_wap1_vol_df

stock_id = 112
pred = all_mvarch_uv_rvol_predicted_df_mean_constant.iloc[91:198][str(stock_id)]
#pred1 = all_mvarch_uv_model_std_predicted_df_mean_constant.iloc[91:198][str(stock_id)]
actual = first_10_min_wap1_vol_df.iloc[91:198][stock_id]


fig, ax1 = plt.subplots()
ax1.plot(range(len(pred)),pred, label='predicted_normal',marker='*',color='red')
ax1.set_ylabel('predicted_normal', color='red')
#ax1.plot(range(len(pred1)),pred1, label='normal_dist',marker='*')
#ax1.plot(range(len(pred1)),pred/pred1, label='pred/std_normal',marker='*',color='black')
ax1.legend()

ax2 = ax1.twinx()
ax2.plot(range(len(actual)),actual, label='actual',marker='*',color='green')
ax2.set_title('stock id: '+str(stock_id))
ax2.legend()
ax2.set_ylabel('actual', color='green')

fig.tight_layout()
######### Evaluation metric #########
## CORRELATION Coefficient is appropriate but
## R^2 = 1 - SSR/SST is just square of correlation coefficient so we can use this!
## SST = Sum of Squared Total, SSR = Sum of squared Residuals




############## Book WAP1 volotitliy end ################
########################################################

# %%
"""
Evaluate Mvarch predictions on trade price volatilities.

"""











############## trade price volotitliy start ##############
##########################################################
#first_10_min_trade_price_vol_df





######### Evaluation metric #########
## R^2




############## trade price volotitliy start ##############
##########################################################
# Out:
# 1551     0.003427
# 22899    0.001338
# 20973    0.006915
# 25234    0.005776
# 5910     0.001878
# 30177    0.003710
# 30940    0.001804
# 18200    0.004778
# 6483     0.002329
# 21139    0.006301
# 7316     0.005496
# 22013    0.001135
# 27851    0.005359
# 18072    0.011131
# Name: 0, dtype: float64
